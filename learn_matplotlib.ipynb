# %%
import matplotlib.pyplot as plt
import pydev
import numpy as np

plt.show()

recorder = pydev.PlotTracker()
recorder.add(1, 0.4)
recorder.add(2, 0.3)
recorder.add(3, 0.1)

plt.plot(recorder.X, recorder.Y, 'r')

#plt.scatter([1,2,1], [1,2,3])

# %%
d = pydev.PlotTracker()
d.load(file('test.plot'))

plt.plot(d.X, d.Y)
