# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-np.pi,np.pi,256,endpoint=True)  
C,S=np.cos(x),np.sin(x)  
plt.plot(x,C)  
plt.plot(x,S)  
plt.show()


plt.plot(x, map(lambda x:x*x+2, x))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def PlotFunction(begin_x, end_x, n_points, func):
    X = np.linspace(begin_x, end_x, n_points, endpoint=True)
    Y = map(lambda x:func(x), X)
    plt.plot(X, Y)
    plt.show()
    

PlotFunction(0.01, 30, 100, lambda x:3.0/(1+math.exp(x/3.0))+0.5)

# %%
import pydev
import math


pydev.function_curve(-5, 5, 0.1, lambda x:1/(1+math.exp(-x)) + 0.001*x)

# %%
pydev.function_curve(-5, 5, 0.1, lambda x:1/(1+math.exp(-x)) + 0.001*x)

# %%
# log-sigmoid

import math

# sigmoid beyond 0.5
def logsigmoid(x):
    return -math.log(1/(1+math.exp(-x)))

# sigmoid beyond 0.5
def sigmoid(x):
    return 1/(1+math.exp(-x))

pydev.function_curve(-10, 10, 0.1, logsigmoid)

print logsigmoid(0)
print sigmoid(0)

print logsigmoid(10)
print sigmoid(10)
# Out:
# 0.69314718056
# 0.5
# 4.53988992168e-05
# 0.999954602131

# %%
import matplotlib.pyplot as plt

X=range(-5,5)
Y=[2,2,3,3,3,2,4,2,1,3]
Z=[3,4,4,2,3,4,3,4,4,3]

plt.plot(X, Y, 'r-', Z)

# %%
pydev.function_curve(6, 30, 0.1, lambda x:x**0.01)
pydev.function_curve(6, 30, 0.1, lambda x:x**0.02)
